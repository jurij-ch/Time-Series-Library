# %%
from matlab_data import ZoneMatData

# %%
antibacterial = ZoneMatData(root_path=r"C:\prj\bacteria\data\Zones\Antib")
print(antibacterial.filenames)
# Out:
# ['SigStat_CutMat_R_0726-0765_C_2371-2410.mat', 'SigStat_CutMat_R_0726-0765_C_2411-2450.mat', 'SigStat_CutMat_R_0726-0765_C_2451-2490.mat', 'SigStat_CutMat_R_0726-0765_C_2491-2530.mat', 'SigStat_CutMat_R_0726-0765_C_2531-2570.mat', 'SigStat_CutMat_R_0806-0845_C_2451-2490.mat', 'SigStat_CutMat_R_0806-0845_C_2491-2530.mat', 'SigStat_CutMat_R_0806-0845_C_2531-2570.mat', 'SigStat_CutMat_R_2006-2045_C_2331-2370.mat', 'SigStat_CutMat_R_2006-2045_C_2371-2410.mat', 'SigStat_CutMat_R_2006-2045_C_2411-2450.mat']

# %%
antibacterial.plot_frame_sigx(time_ind=0, sample_name=antibacterial.filenames[0])

# %%
antibacterial.plot_ts_sigx(0, 3, 0, 3, antibacterial.filenames[0], with_mean=False)

# %%
antibacterial.plot_ts_sigx(1, 1, 1, 1, antibacterial.filenames[0], with_mean=False)

# %%
inh_zone = ZoneMatData(root_path=r"C:/prj/bacteria/data/Zones/Inhibition_Zone", end_time_ind = 1440)
print(inh_zone.filenames)
# Out:
# ['SigStat_CutMat_R_0366-0405_C_2371-2410.mat', 'SigStat_CutMat_R_0366-0405_C_2411-2450.mat', 'SigStat_CutMat_R_0366-0405_C_2451-2490.mat', 'SigStat_CutMat_R_0726-0765_C_2171-2210.mat', 'SigStat_CutMat_R_0726-0765_C_2211-2250.mat', 'SigStat_CutMat_R_0766-0805_C_2171-2210.mat', 'SigStat_CutMat_R_0766-0805_C_2211-2250.mat', 'SigStat_CutMat_R_1046-1085_C_2331-2370.mat', 'SigStat_CutMat_R_1046-1085_C_2371-2410.mat', 'SigStat_CutMat_R_1046-1085_C_2411-2450.mat', 'SigStat_CutMat_R_1766-1805_C_2331-2370.mat', 'SigStat_CutMat_R_1766-1805_C_2371-2410.mat', 'SigStat_CutMat_R_2246-2285_C_2091-2130.mat', 'SigStat_CutMat_R_2246-2285_C_2131-2170.mat']

# %%
inh_zone.T
# Out:
# 1440

# %%
inh_zone.plot_ts_sigx(1, 1, 1, 1, inh_zone.filenames[0], with_mean=False)

# %%
inh_zone.T
# Out:
# 1440

# %%
out_zone = ZoneMatData(root_path=r"C:/prj/bacteria/data/Zones/Out_of_Zone", end_time_ind = 1440)
print(out_zone.filenames)
# Out:
# ['SigStat_CutMat_R_0206-0245_C_1171-1210.mat', 'SigStat_CutMat_R_0206-0245_C_1211-1250.mat', 'SigStat_CutMat_R_0206-0245_C_1251-1290.mat', 'SigStat_CutMat_R_0206-0245_C_1291-1330.mat', 'SigStat_CutMat_R_1406-1445_C_1211-1250.mat', 'SigStat_CutMat_R_1406-1445_C_1251-1290.mat', 'SigStat_CutMat_R_1406-1445_C_1291-1330.mat', 'SigStat_CutMat_R_1406-1445_C_1331-1370.mat', 'SigStat_CutMat_R_1406-1445_C_1371-1410.mat', 'SigStat_CutMat_R_1726-1765_C_3451-3490.mat', 'SigStat_CutMat_R_1726-1765_C_3491-3530.mat', 'SigStat_CutMat_R_1726-1765_C_3531-3570.mat']

# %%
out_zone.T
# Out:
# 1440

# %%
out_zone.plot_ts_sigx(1, 1, 1, 1, out_zone.filenames[0], with_mean=False)

# %%
out_zone.export_to_df()
